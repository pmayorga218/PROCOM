# %%
import random 
o=['Piedra', 'Papel','Tijera','Lagarto','Papa','Heavy', 'Spock']
bot=random.randint(0,6)
r=o[bot]
print(f"Te enfrentas contra {r}")
p=int(input("Escoge con cual te defiendes 1)Piedra, 2)Papel, 3)Tijera, 4)Spock, 5)Lagarto, 6)Papa o 7)Heavy"))

if p==1:
  if (r=="Papel"):
    print("Ganaste")
  elif (r=="Piedra"):
    print("Perdiste")
  elif (r=="Lagarto"):
    print("Ganaste")
  elif (r=="Spock"):
    print("Perdiste")
  elif (r=="Papa"):
    print("Perdiste")
  elif (r=="Heavy"):
    print("Ganaste")
elif p==2:
  if (r=="Tijera"):
    print("Perdiste")
  elif (r=="Piedra"):
    print("Ganaste")
  elif (r=="Spock"):
    print("Ganaste")
  elif (r=="Lagarto"):
    print("Perdiste")
  elif (r=="Papa"):
    print("Perdiste")
  elif (r=="Heavy"):
    print("Ganaste")
elif p==3:
  if (r=="Tijera"):
    print("Ganaste")
  elif (r=="Papel"):
    print("Perdiste")
  elif (r=="Lagardo"):
    print("Ganaste")
  elif (r=="Heavy"):
    print("Ganaste")
  elif (r=="Papa"):
    print("Perdiste")
  elif (r=="Heavy"):
    print("Ganaste")
elif p==4:
  if (r=="Spock"):
    print("Perdiste")
  elif (r=="Papel"):
    print("Ganaste")
  elif (r=="Papa"):
    print("Perdiste")
  elif (r=="Papa"):
    print("Ganaste")
  elif (r=="Heavy"):
    print("Perdiste")
  elif (r=="Piedra"):
    print("Perdiste")
elif p== 5:
  if (r=="Tijera"):
    print("Ganaste")
  elif (r=="Piedra"):
    print("Ganaste")
  elif (r=="Papa"):
    print("Ganaste")
  elif (r=="Lagarto"):
    print("Perdiste")
  elif (r=="Heavy"):
    print("Perdiste")
  elif (r=="Papel"):
    print("Perdiste")
elif p==6:
  if (r=="Spock"):
    print("Ganaste")
  elif (r=="Lagarto"):
    print("Ganaste")
  elif (r=="Papa"):
    print("Ganaste")
  elif (r=="Piedra"):
    print("Perdiste")
  elif (r=="Papel"):
    print("Perdiste")
  elif (r=="Tijera"):
    print("Perdiste")
elif p==7:
  if (r=="Tijera"):
    print("Ganaste")
  elif (r=="Papel"):
    print("Ganaste")
  elif (r=="Piedra"):
    print("Ganaste")
  elif (r=="Spock"):
    print("Perdiste")
  elif (r=="Lagarto"):
    print("Perdiste")
  elif (r=="Heavy"):
    print("Perdiste")
else:
  print("Ingresa una opción válida")
# Out:
# La elección del compu es:  Heavy
# Digita tu elección así tal cual: 1)Piedra, 2)Papel, 3)Tijera, 4)Spock, 5)Lagarto, 6)Papa o 7)Heavy2
# Perdiste
