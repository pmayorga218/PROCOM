# %%
combos={"combo 1":20000, "combo 2":25000, "combo 3":18000, "combo 4":24500, "papas":3000, "jugos naturales":7000, "cerveza":3500, "agua":4000, "gaseosas":2500}
print("Bienvenido a la tienda")
print("Combo 1  $20000 \nCombo 2  $25000 \nCombo 3  $18000 \nCombo 4 $24500 \nPapas $3000 \nJugos naturales $7000 \nCerveza 35000 \nAgua 4000 \nGaseosas 2500")
c=int(input("Ingresa el combo que deseas (1, 2, 3 o 4), si no deseas ninguno, ingresa 0"))
if c == 1:
  print(combos["combo 1"])
  m=int(input("Deseas algo más? Ingresa 1 para si, 2 para no"))
  if m ==1:
    c=int(input("Ingresa el combo que deseas (1, 2, 3 o 4), si no deseas ninguno, ingresa 0"))
  else:
    a=int(input("Deseas solo un adicional(papas)? o alguna bebida? Escribe 1 para papas y 2 para bebida o 3 si quieres terminar el pedido"))
    if a == 1:
     print(combos["papas"])
    elif a ==2:
     b=int(input("Qué bebida deseas? Ingresa 1 para jugos naturales, 2 para cerveza, 3 para agua o 4 para gaseosas"))
    if b ==1:
      print(combos["jugos naturales"])
    elif b ==2:
      print(combos["cerveza"])
    elif b ==3:
      print(combos["agua"])
    elif b ==4:
      print(combos["gaseosas"])
    else:
      print("Ingresa una opción correcta")    
elif c == 2:
  print(combos["combo 2"])
  m=int(input("Deseas algo más? Ingresa 1 para si, 2 para no"))
  if m ==1:
    c=int(input("Ingresa el combo que deseas (1, 2, 3 o 4), si no deseas ninguno, ingresa 0"))
  else:
    a=int(input("Deseas solo un adicional(papas)? o alguna bebida? Escribe 1 para papas y 2 para bebida o 3 si quieres terminar el pedido"))
    if a == 1:
     print(combos["papas"])
    elif a ==2:
     b=int(input("Qué bebida deseas? Ingresa 1 para jugos naturales, 2 para cerveza, 3 para agua o 4 para gaseosas"))
    if b ==1:
      print(combos["jugos naturales"])
    elif b ==2:
      print(combos["cerveza"])
    elif b ==3:
      print(combos["agua"])
    elif b ==4:
      print(combos["gaseosas"])
    else:
      print("Ingresa una opción correcta")
elif c == 3:
  print(combos["combo 3"])
  m=int(input("Deseas algo más? Ingresa 1 para si, 2 para no"))
  if m ==1:
    c=int(input("Ingresa el combo que deseas (1, 2, 3 o 4), si no deseas ninguno, ingresa 0"))
  else:
    a=int(input("Deseas solo un adicional(papas)? o alguna bebida? Escribe 1 para papas y 2 para bebida o 3 si quieres terminar el pedido"))
    if a == 1:
     print(combos["papas"])
    elif a ==2:
     b=int(input("Qué bebida deseas? Ingresa 1 para jugos naturales, 2 para cerveza, 3 para agua o 4 para gaseosas"))
    if b ==1:
      print(combos["jugos naturales"])
    elif b ==2:
      print(combos["cerveza"])
    elif b ==3:
      print(combos["agua"])
    elif b ==4:
      print(combos["gaseosas"])
    else:
      print("Ingresa una opción correcta")    
elif c == 4:
  print(combos["combo 4"])
  m=int(input("Deseas algo más? Ingresa 1 para si, 2 para no"))
  if m ==1:
    c=int(input("Ingresa el combo que deseas (1, 2, 3 o 4), si no deseas ninguno, ingresa 0"))
  else:
    a=int(input("Deseas solo un adicional(papas)? o alguna bebida? Escribe 1 para papas y 2 para bebida o 3 si quieres terminar el pedido"))
    if a == 1:
     print(combos["papas"])
    elif a ==2:
     b=int(input("Qué bebida deseas? Ingresa 1 para jugos naturales, 2 para cerveza, 3 para agua o 4 para gaseosas"))
    if b ==1:
      print(combos["jugos naturales"])
    elif b ==2:
      print(combos["cerveza"])
    elif b ==3:
      print(combos["agua"])
    elif b ==4:
      print(combos["gaseosas"])
    else:
      print("Ingresa una opción correcta")
elif c == 0:
  a=int(input("Deseas solo un adicional(papas)? o alguna bebida? Escribe 1 para papas y 2 para bebida o 3 si quieres terminar el pedido"))
  if a == 1:
    print(combos["papas"])
  elif a ==2:
    b=int(input("Qué bebida deseas? Ingresa 1 para jugos naturales, 2 para cerveza, 3 para agua o 4 para gaseosas"))
    if b ==1:
      print(combos["jugos naturales"])
    elif b ==2:
      print(combos["cerveza"])
    elif b ==3:
      print(combos["agua"])
    elif b ==4:
      print(combos["gaseosas"])
    else:
      print("Ingresa una opción correcta")

else:
  print("Selecciona una opción válida")
# Out:
# Bienvenido a la tienda
# Combo 1  $20000
# Combo 2  $25000
# Combo 3  $18000
# Combo 4 $24500
# Papas $3000
# Jugos naturales $7000
# Cerveza 35000
# Agua 4000
# Gaseosas 2500
# Ingresa el combo que deseas (1, 2, 3 o 4), si no deseas ninguno, ingresa 00
# Deseas solo un adicional(papas)? o alguna bebida? Escribe 1 para papas y 2 para bebida o 3 si quieres terminar el pedido2
# Qué bebida deseas? Ingresa 1 para jugos naturales, 2 para cerveza, 3 para agua o 4 para gaseosas1
# 7000
